# %% [markdown]
# **CIÊNCIA DOS DADOS PARA TOMADAS DE DECISÕES**
#
# Aluno: Renan Prado
#
# Professor(a): Sergio Ricardo
#
# Tema: Aplicação Prática de Python na Ciência dos Dados

# %%
conda list
# Out:
# # packages in environment at C:\Users\Ronnie\anaconda3:
# Note: you may need to restart the kernel to use updated packages.
#
# #
# # Name                             Version              Build                Channel
# _anaconda_depends                  2025.06              py313_mkl_2
# aext-assistant                     4.20.0               py313haa95532_jl4_0
# aext-assistant-server              4.20.0               py313haa95532_0
# aext-core                          4.20.0               py313haa95532_jl4_0
# aext-core-server                   4.20.0               py313haa95532_0
# aext-environments-server           4.20.0               py313haa95532_0
# aext-panels                        4.20.0               py313haa95532_0
# aext-panels-server                 4.20.0               py313haa95532_0
# aext-project-filebrowser-server    4.20.0               py313haa95532_0
# aext-share-notebook                4.20.0               py313haa95532_0
# ...

# %%
    import pandas as pd

# %%
df = pd.read_excel('default_of_credit_card_clients__courseware_version_1_21_19 (3).xls')
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df['default payment next month'].value_counts()
# Out:
# default payment next month
# 0    23438
# 1     6562
# Name: count, dtype: int64

# %% [markdown]
# ### Respostas
#
# 1. **Quantas colunas os dados contêm?**
#
#    São **25 colunas** no total: 1 ID, 23 características e 1 variável alvo (`default payment next month`).
#
# 3. **Quantas linhas (amostras)?**
#
#    **30.000 linhas** (30.000 contas de clientes analisadas).
#
# 5. **Que tipos de características existem? Categóricas vs Numéricas**
#
#    Todas as colunas aparecem como **int64** (números inteiros), mas na prática:
#
#    - **Categóricas** (valores discretos/codificados):
#      SEX, EDUCATION, MARRIAGE, PAY_1 até PAY_6, default payment next month
#
#    - **Numéricas** (escala contínua ou quantidades):
#      LIMIT_BAL, AGE, BILL_AMT1 a BILL_AMT6, PAY_AMT1 a PAY_AMT6
#
# 7. **Qual é a aparência dos dados?**
#
#    - Inadimplência: 78,1% não (0) e 21,9% sim (1) – desbalanceado.
#    - Idade: média 35,1 anos (maioria entre 28 e 41).
#    - Limite de crédito: média ~168 mil NT$, mediana 140 mil, máximo 1 milhão.
#    - Faturas (BILL_AMT): médias entre 35–52 mil, alguns valores negativos (crédito a favor).
#    - Pagamentos (PAY_AMT): médias ~5–6 mil, muitos baixos, mas alguns bem altos.
#    - Status de pagamento (PAY_1–6): maioria em dia ou com atraso pequeno (valores negativos ou 0 predominam).
#
# 9. **Existem dados faltando?**
#
#    **Não**. Zero valores faltantes em todas as colunas (dataset limpo).
#
#
#    ...
