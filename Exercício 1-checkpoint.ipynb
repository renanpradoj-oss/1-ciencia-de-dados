# %% [markdown]
# ## Exercício 1 – Familiarização com Python (feito no Jupyter Notebook)

# %% [markdown]
# ### 3. Crie um loop for no prompt de comando para exibir os valores de 0 a 4

# %%
for counter in range(5):
    print(counter)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### 4. Crie um dicionário de frutas (apples [maçãs], oranges [laranjas] e bananas [bananas])

# %%
example_dict = {'apples': 5, 'oranges': 8, 'bananas': 13}
example_dict
# Out:
# {'apples': 5, 'oranges': 8, 'bananas': 13}

# %% [markdown]
# ### 5. Converta o dicionário em uma lista usando a função list()

# %%
dict_to_list = list(example_dict)
dict_to_list
# Out:
# ['apples', 'oranges', 'bananas']
